# %%
'''
get_results <- function(rtid) {
  
  # SCRAPE ----
  # get events for a given route ('rtid')
  route_url <- function(rtid) {
    glue("https://rusa.org/cgi-bin/resultsearch_PF.pl?",
         "regid=&date=&type=&dist=&",
         "rtid={rtid}",
         "&esortby=cert&",
         "collapse=1", rtid=rtid)
  }
  route_results <- 
    route_url(rtid) %>%
    read_html
  dat <- route_results %>%
    html_nodes('table') %>%
    html_table %>%
    .[[1]]
  
  # CLEAN -----
  # remove the 'x nonmember(s) also finished this event' rows
  bad_rows <- grepl('also finished this event$', dat[[1]])
  dat <- dat[!bad_rows,]
  
  # find 'event divider rows' -- the remaining ones where every column is the same
  all_same <- function(x) all(x==x[1])
  event_rows <- apply(dat, 1, all_same)
  
  # add event date as own field:
  # 1) pull the dates
  extracted_dates <- 
    dat[event_rows, 1] %>% 
    stringr::str_extract('[0-9]{4}/[0-9]{2}/[0-9]{2}') %>%
    ymd
  class(extracted_dates)
  # 2) add empty date column
  dat[['event_date']] <- as.Date(NA)
  
  # 3) fill in values at each position where a new event starts
  dat[event_rows, 'event_date'] <- extracted_dates
  
  # 4) lastly, carry those dates foreward over missing values, filling every row
  dat[['event_date']] <- zoo::na.locf(dat[['event_date']])
  
  # now we can drop these 'event divider' rows
  dat <- dat[!event_rows,]
  
  # type conversion
  dat$Time <- hm(dat$Time)
  dat$time_hours <- as.numeric(dat$Time)/60/60
  
  # append rtid as attribute
  attr(dat, 'rtid') <- rtid
  
  return(dat)
}
'''

# %%
def rusa_result_url(rtid):
    url = f"https://rusa.org/cgi-bin/resultsearch_PF.pl?rtid={rtid}&collapse=1"
    return(url)

# %%
import pandas as pd
import numpy as np

# %%
rtid = 1158
# read data, keep just the first table (the only one)
dat = pd.read_html(rusa_result_url(rtid))
dat = dat[0]

# %%
dat.shape
# remove the 'x nonmember(s) also finished this event' rows
bad_rows = dat['Cert#'].str.contains('also finished this event')
dat = dat[~bad_rows]
dat.shape
# Out:
# (1118, 5)

# %%
# find 'event divider rows' -- the remaining ones where every column is the same
event_rows = dat.apply(lambda x: len(set(x)) == 1, axis=1)

# %%
# extract event dates
extracted_dates = dat[event_rows].iloc[:,1].str.extract(r'([0-9]{4}/[0-9]{2}/[0-9]{2})')

# %%
# new column
dat['event_date'] = np.NaN

# fill in values at each position where a new event starts
dat.loc[event_rows, 'event_date'] =  extracted_dates.iloc[:,0]

# %%
dat = dat.fillna(method="ffill")
dat
# Out:
#                                                   Cert#  \
# 0     CA: San Francisco RUSAB 200 km 2011/11/05 fini...
# 1                                           RUSA-B07069
# 2                                           RUSA-B07070
# 3                                           RUSA-B07071
# 4                                           RUSA-B07073
# ...                                                 ...
# 1122                                             826190
# 1123                                             826191
# 1124                                             826192
# 1125                                             826193
# 1126                                             826194
#
#                                                   RUSA#  \
# 0     CA: San Francisco RUSAB 200 km 2011/11/05 fini...
# 1                                                  7033
# 2                                                  6056
# 3                                                  6566
# 4                                                  7184
# ...                                                 ...
# 1122                                               6373
# 1123                                               7268
# 1124                                              15118
# 1125                                              14760
# 1126                                              12425
#
#                                                    Name  \
# 0     CA: San Francisco RUSAB 200 km 2011/11/05 fini...
# 1                                     ALEXANDER, Cory E
# 2                                          ALLEN, Heath
# 3                                    ALLEN, Scott Wayne
# 4                                 BARKER, Christopher D
# ...                                                 ...
# 1122                                    Wilson, Charles
# 1123                                      Wilson, James
# 1124                                        Wu, Jasmine
# 1125                                     Zabell, Howard
# 1126                                      Zorn, Michael
#
#                                                    Club  \
# 0     CA: San Francisco RUSAB 200 km 2011/11/05 fini...
# 1                              Randonneurs USA / 950095
# 2                             Maui Randonneurs / 911003
# 3                      Santa Rosa Cycling Club / 905048
# 4                    San Francisco Randonneurs / 905030
# ...                                                 ...
# 1122                 San Francisco Randonneurs / 905030
# 1123                 San Francisco Randonneurs / 905030
# 1124                 San Francisco Randonneurs / 905030
# 1125                              Cycle Folsom / 905169
# 1126                 San Francisco Randonneurs / 905030
#
#                                                    Time  event_date
# 0     CA: San Francisco RUSAB 200 km 2011/11/05 fini...  2011/11/05
# 1                                                 08:21  2011/11/05
# 2                                                 09:29  2011/11/05
# 3                                                 13:06  2011/11/05
# 4                                                 11:09  2011/11/05
# ...                                                 ...         ...
# 1122                                              07:36  2022/02/19
# 1123                                              11:16  2022/02/19
# 1124                                              08:36  2022/02/19
# 1125                                              09:43  2022/02/19
# 1126                                              11:00  2022/02/19
#
# [1118 rows x 6 columns]

# %%
# now we can drop these 'event divider' rows
dat = dat[~event_rows]

# %%
dat
# Out:
#             Cert#  RUSA#                   Name  \
# 1     RUSA-B07069   7033      ALEXANDER, Cory E
# 2     RUSA-B07070   6056           ALLEN, Heath
# 3     RUSA-B07071   6566     ALLEN, Scott Wayne
# 4     RUSA-B07073   7184  BARKER, Christopher D
# 5     RUSA-B07074   4269           BEATO, Keith
# ...           ...    ...                    ...
# 1122       826190   6373        Wilson, Charles
# 1123       826191   7268          Wilson, James
# 1124       826192  15118            Wu, Jasmine
# 1125       826193  14760         Zabell, Howard
# 1126       826194  12425          Zorn, Michael
#
#                                     Club   Time  event_date
# 1               Randonneurs USA / 950095  08:21  2011/11/05
# 2              Maui Randonneurs / 911003  09:29  2011/11/05
# 3       Santa Rosa Cycling Club / 905048  13:06  2011/11/05
# 4     San Francisco Randonneurs / 905030  11:09  2011/11/05
# 5     San Francisco Randonneurs / 905030  11:09  2011/11/05
# ...                                  ...    ...         ...
# 1122  San Francisco Randonneurs / 905030  07:36  2022/02/19
# 1123  San Francisco Randonneurs / 905030  11:16  2022/02/19
# 1124  San Francisco Randonneurs / 905030  08:36  2022/02/19
# 1125               Cycle Folsom / 905169  09:43  2022/02/19
# 1126  San Francisco Randonneurs / 905030  11:00  2022/02/19
#
# [1105 rows x 6 columns]

# %%
# add route id as column
dat['route_id'] = rtid
dat
# Out:
#             Cert#  RUSA#                   Name  \
# 1     RUSA-B07069   7033      ALEXANDER, Cory E
# 2     RUSA-B07070   6056           ALLEN, Heath
# 3     RUSA-B07071   6566     ALLEN, Scott Wayne
# 4     RUSA-B07073   7184  BARKER, Christopher D
# 5     RUSA-B07074   4269           BEATO, Keith
# ...           ...    ...                    ...
# 1122       826190   6373        Wilson, Charles
# 1123       826191   7268          Wilson, James
# 1124       826192  15118            Wu, Jasmine
# 1125       826193  14760         Zabell, Howard
# 1126       826194  12425          Zorn, Michael
#
#                                     Club   Time  event_date  route_id
# 1               Randonneurs USA / 950095  08:21  2011/11/05      1158
# 2              Maui Randonneurs / 911003  09:29  2011/11/05      1158
# 3       Santa Rosa Cycling Club / 905048  13:06  2011/11/05      1158
# 4     San Francisco Randonneurs / 905030  11:09  2011/11/05      1158
# 5     San Francisco Randonneurs / 905030  11:09  2011/11/05      1158
# ...                                  ...    ...         ...       ...
# 1122  San Francisco Randonneurs / 905030  07:36  2022/02/19      1158
# 1123  San Francisco Randonneurs / 905030  11:16  2022/02/19      1158
# 1124  San Francisco Randonneurs / 905030  08:36  2022/02/19      1158
# 1125               Cycle Folsom / 905169  09:43  2022/02/19      1158
# 1126  San Francisco Randonneurs / 905030  11:00  2022/02/19      1158
#
# [1105 rows x 7 columns]
